# %%
import spacy

# %% [markdown]
# Write a function called n_grams that takes as input a spaCy Document, and returns a list of all
# of the n_grams in the document.

# %%
def n_gram(doc,n):
    # Viết code của bạn tại đây
    tokens = [token.text for token in doc]

    ngrams = []

    for i in range(len(tokens) - n + 1):
        ngram = ' '.join(tokens[i:i+n])
        ngrams.append(ngram)

    return ngrams

# %%
from spacy.lang.en import English
nlp = English(pipeline=[], max_length=5000000)
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print((token))
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion

# %%
n_gram(doc,2)
# Out:
# ['Apple is',
#  'is looking',
#  'looking at',
#  'at buying',
#  'buying U.K.',
#  'U.K. startup',
#  'startup for',
#  'for $',
#  '$ 1',
#  '1 billion']
